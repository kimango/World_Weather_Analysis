# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import requests

from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e1579bf6da3b261baf9210860b701af3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | labuhan
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | henties bay
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | guerrero negro
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | kologriv
# Processing Record 12 of Set 1 | vieste
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | saurimo
# Processing Record 15 of Set 1 | port hardy
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | fonte boa
# Processing Record 18 of Set 1 | ojinaga
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | severnyy-kospashskiy
# Processing Record 21 of Set 1 | timra
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | vao
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | saint-augustin
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | bunia
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | constitucion
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | tadine
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | carikar
# City not found. Skipping...
# Processing Record 45 of Set 1 | debre birhan
# Processing Record 46 of Set 1 | port macquarie
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | coihaique
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | los llanos de aridane
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | san quintin
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | baft
# Processing Record 5 of Set 2 | berlevag
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | mashhad
# Processing Record 9 of Set 2 | hovd
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | oriximina
# Processing Record 12 of Set 2 | gat
# Processing Record 13 of Set 2 | goderich
# Processing Record 14 of Set 2 | naze
# Processing Record 15 of Set 2 | trincomalee
# Processing Record 16 of Set 2 | yazman
# Processing Record 17 of Set 2 | adrar
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | ialibu
# Processing Record 22 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 2 | olinda
# Processing Record 24 of Set 2 | dunedin
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | sao joao da barra
# Processing Record 27 of Set 2 | general pico
# Processing Record 28 of Set 2 | tukrah
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | honiara
# Processing Record 31 of Set 2 | winona
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | ikalamavony
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | falakata
# Processing Record 38 of Set 2 | turayf
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | zhaotong
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 2 | toora-khem
# Processing Record 45 of Set 2 | quijingue
# Processing Record 46 of Set 2 | sire
# Processing Record 47 of Set 2 | san cristobal
# Processing Record 48 of Set 2 | ocos
# Processing Record 49 of Set 2 | samarai
# Processing Record 50 of Set 2 | tabou
# Processing Record 1 of Set 3 | rudnyy
# Processing Record 2 of Set 3 | clyde
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | iquique
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | camacha
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | isabela
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | dryden
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | arlit
# Processing Record 16 of Set 3 | ruse
# Processing Record 17 of Set 3 | avera
# Processing Record 18 of Set 3 | namatanai
# Processing Record 19 of Set 3 | itaquyry
# Processing Record 20 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 3 | normandin
# Processing Record 22 of Set 3 | leh
# Processing Record 23 of Set 3 | ahja
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | acari
# Processing Record 26 of Set 3 | praia da vitoria
# Processing Record 27 of Set 3 | dicabisagan
# Processing Record 28 of Set 3 | tupik
# Processing Record 29 of Set 3 | grindavik
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | sioux lookout
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | lichuan
# Processing Record 35 of Set 3 | dubrovnik
# Processing Record 36 of Set 3 | asau
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | tura
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | mount pleasant
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | kakamigahara
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | maxixe
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 4 | basoko
# Processing Record 4 of Set 4 | vanavara
# Processing Record 5 of Set 4 | pocatello
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | kuching
# Processing Record 10 of Set 4 | beipiao
# Processing Record 11 of Set 4 | tilichiki
# Processing Record 12 of Set 4 | catamarca
# Processing Record 13 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | westport
# Processing Record 16 of Set 4 | jharsuguda
# Processing Record 17 of Set 4 | chipata
# Processing Record 18 of Set 4 | hit
# Processing Record 19 of Set 4 | port blair
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | evensk
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | nome
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 4 | rongcheng
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | lantana
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | grants
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | aquiraz
# Processing Record 35 of Set 4 | pahrump
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | teya
# Processing Record 38 of Set 4 | satun
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | sayat
# Processing Record 41 of Set 4 | lata
# Processing Record 42 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | kloulklubed
# Processing Record 45 of Set 4 | maudaha
# Processing Record 46 of Set 4 | lipin bor
# Processing Record 47 of Set 4 | souillac
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | katsuura
# Processing Record 50 of Set 4 | pangai
# Processing Record 1 of Set 5 | nayoro
# Processing Record 2 of Set 5 | laguna
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | arona
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | izhma
# Processing Record 8 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 9 of Set 5 | jagdalpur
# Processing Record 10 of Set 5 | colares
# Processing Record 11 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | watertown
# Processing Record 15 of Set 5 | naifaru
# Processing Record 16 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | durham
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | carballo
# Processing Record 21 of Set 5 | fortuna
# Processing Record 22 of Set 5 | sumbawanga
# Processing Record 23 of Set 5 | vagur
# Processing Record 24 of Set 5 | svetlyy yar
# Processing Record 25 of Set 5 | kiunga
# Processing Record 26 of Set 5 | mayo
# Processing Record 27 of Set 5 | santiago de compostela
# Processing Record 28 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 5 | marzuq
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | ossora
# Processing Record 32 of Set 5 | victoria
# Processing Record 33 of Set 5 | kieta
# Processing Record 34 of Set 5 | seoul
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | danjiangkou
# Processing Record 37 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | menongue
# Processing Record 41 of Set 5 | kaabong
# Processing Record 42 of Set 5 | hilo
# Processing Record 43 of Set 5 | pillaro
# Processing Record 44 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 45 of Set 5 | parrita
# Processing Record 46 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 5 | bozdar
# Processing Record 48 of Set 5 | hay river
# Processing Record 49 of Set 5 | quatre cocos
# Processing Record 50 of Set 5 | bannu
# Processing Record 1 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 2 of Set 6 | lewiston
# Processing Record 3 of Set 6 | saint anthony
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | chegutu
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | pochutla
# Processing Record 8 of Set 6 | baherden
# Processing Record 9 of Set 6 | benguela
# Processing Record 10 of Set 6 | fairbanks
# Processing Record 11 of Set 6 | port-gentil
# Processing Record 12 of Set 6 | muisne
# Processing Record 13 of Set 6 | carahue
# Processing Record 14 of Set 6 | batemans bay
# Processing Record 15 of Set 6 | savannah bight
# Processing Record 16 of Set 6 | kibre mengist
# Processing Record 17 of Set 6 | maniitsoq
# Processing Record 18 of Set 6 | kuhdasht
# Processing Record 19 of Set 6 | xichang
# Processing Record 20 of Set 6 | makakilo city
# Processing Record 21 of Set 6 | marsabit
# Processing Record 22 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | maldonado
# Processing Record 24 of Set 6 | oudtshoorn
# Processing Record 25 of Set 6 | belaya gora
# Processing Record 26 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 6 | tandil
# Processing Record 29 of Set 6 | batagay-alyta
# Processing Record 30 of Set 6 | yulara
# Processing Record 31 of Set 6 | ixtapa
# Processing Record 32 of Set 6 | jilib
# Processing Record 33 of Set 6 | lovozero
# Processing Record 34 of Set 6 | knappskog
# Processing Record 35 of Set 6 | qiqihar
# Processing Record 36 of Set 6 | mehamn
# Processing Record 37 of Set 6 | huaiyin
# Processing Record 38 of Set 6 | mut
# Processing Record 39 of Set 6 | ugoofaaru
# Processing Record 40 of Set 6 | barcelos
# Processing Record 41 of Set 6 | raudeberg
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | shelbyville
# Processing Record 44 of Set 6 | opuwo
# Processing Record 45 of Set 6 | iskateley
# Processing Record 46 of Set 6 | dwarka
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | sitka
# Processing Record 49 of Set 6 | west bay
# Processing Record 50 of Set 6 | smithers
# Processing Record 1 of Set 7 | roald
# Processing Record 2 of Set 7 | abha
# Processing Record 3 of Set 7 | pemangkat
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | slantsy
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | albion
# Processing Record 9 of Set 7 | savelugu
# Processing Record 10 of Set 7 | rognan
# Processing Record 11 of Set 7 | shimoda
# Processing Record 12 of Set 7 | fort-shevchenko
# Processing Record 13 of Set 7 | platanos
# Processing Record 14 of Set 7 | sucua
# Processing Record 15 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 16 of Set 7 | douglas
# Processing Record 17 of Set 7 | leon
# Processing Record 18 of Set 7 | bulnes
# Processing Record 19 of Set 7 | meulaboh
# Processing Record 20 of Set 7 | ust-nera
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | plettenberg bay
# Processing Record 23 of Set 7 | asuncion
# Processing Record 24 of Set 7 | tessalit
# Processing Record 25 of Set 7 | shitanjing
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | lulea

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp -34.5322   20.0403     56.28        36           5
# 1         Labuhan  -6.8844  112.2051     79.11        81          19
# 2        Saldanha -33.0117   17.9442     68.02        37           2
# 3     Henties Bay -22.1160   14.2845     67.86        47           0
# 4    Punta Arenas -53.1500  -70.9167     39.31        81           0
# 5      Nikolskoye  59.7035   30.7861     58.89        87          72
# 6       Busselton -33.6500  115.3333     47.08        78           0
# 7  Guerrero Negro  27.9769 -114.0611     67.53        64          74
# 8         Mataura -46.1927  168.8643     49.48        70          49
# 9        Cherskiy  68.7500  161.3000     69.48        34          89
#
#    Wind Speed Country                 Date
# 0        7.34      ZA  2021-06-07 00:10:55
# 1        7.38      ID  2021-06-07 00:03:23
# 2       27.27      ZA  2021-06-07 00:10:56
# 3        7.81      NA  2021-06-07 00:10:57
# 4       10.25      CL  2021-06-07 00:08:35
# 5        3.18      RU  2021-06-07 00:10:57
# 6        7.25      AU  2021-06-07 00:10:58
# 7       16.55      MX  2021-06-07 00:01:35
# 8        4.09      NZ  2021-06-07 00:10:58
# 9       19.53      RU  2021-06-07 00:02:21

# %%
city_data_df = city_data_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0      Bredasdorp      ZA  2021-06-07 00:10:55 -34.5322   20.0403     56.28
# 1         Labuhan      ID  2021-06-07 00:03:23  -6.8844  112.2051     79.11
# 2        Saldanha      ZA  2021-06-07 00:10:56 -33.0117   17.9442     68.02
# 3     Henties Bay      NA  2021-06-07 00:10:57 -22.1160   14.2845     67.86
# 4    Punta Arenas      CL  2021-06-07 00:08:35 -53.1500  -70.9167     39.31
# 5      Nikolskoye      RU  2021-06-07 00:10:57  59.7035   30.7861     58.89
# 6       Busselton      AU  2021-06-07 00:10:58 -33.6500  115.3333     47.08
# 7  Guerrero Negro      MX  2021-06-07 00:01:35  27.9769 -114.0611     67.53
# 8         Mataura      NZ  2021-06-07 00:10:58 -46.1927  168.8643     49.48
# 9        Cherskiy      RU  2021-06-07 00:02:21  68.7500  161.3000     69.48
#
#    Humidity  Cloudiness  Wind Speed
# 0        36           5        7.34
# 1        81          19        7.38
# 2        37           2       27.27
# 3        47           0        7.81
# 4        81           0       10.25
# 5        87          72        3.18
# 6        78           0        7.25
# 7        64          74       16.55
# 8        70          49        4.09
# 9        34          89       19.53

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
output_data_file
